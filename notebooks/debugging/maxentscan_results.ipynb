# %%
import pandas as pd

# %%
directory = "/n/scratch3/users/d/djl34/downloads/whole_gene/"

filename = "4_regions_split_11_rate_v5.2_TFBS_correction_wholegene.MaxEntScan.tsv"

# %%
df = pd.read_csv(directory + filename, sep = "\t", names = ['CHROM', 'POS', 'REF', 'ALT', 'Consequence', 'Gene', 'Feature', 'MaxEntScan_alt', 'MaxEntScan_diff', 'MaxEntScan_ref'])

# %%
df[df["MaxEntScan_alt"] != "."]
# Out:
#          CHROM       POS REF ALT  \
# 300732       4  15263391   T   A
# 300733       4  15263391   T   C
# 300734       4  15263391   T   G
# 300735       4  15263392   C   A
# 300736       4  15263392   C   G
# ...        ...       ...  ..  ..
# 2395180      4  16226257   A   G
# 2395181      4  16226257   A   T
# 2395182      4  16226258   C   A
# 2395183      4  16226258   C   G
# 2395184      4  16226258   C   T
#
#                                                Consequence             Gene  \
# 300732   splice_donor_region_variant&intron_variant&non...  ENSG00000249252
# 300733   splice_donor_region_variant&intron_variant&non...  ENSG00000249252
# 300734   splice_donor_region_variant&intron_variant&non...  ENSG00000249252
# 300735   splice_donor_5th_base_variant&intron_variant&n...  ENSG00000249252
# 300736   splice_donor_5th_base_variant&intron_variant&n...  ENSG00000249252
# ...                                                    ...              ...
# ...

# %%
df["Feature"].unique()
# Out:
# array(['ENST00000362550', 'ENST00000502344', 'ENST00000444304',
#        'ENST00000424120', 'ENST00000341285', 'ENST00000422728',
#        'ENST00000265016', 'ENST00000513715', 'ENST00000226279',
#        'ENST00000509498', 'ENST00000382333', 'ENST00000259989',
#        'ENST00000447510', 'ENST00000666747', 'ENST00000405303'],
#       dtype=object)
