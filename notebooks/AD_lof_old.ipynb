# %%
import os
import dask.dataframe as dd
from dask.distributed import Client
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)


pd_data_dir = "/home/djl34/lab_pd/data"
aso_data_dir = "/home/djl34/lab_pd/aso/data"
KL_data_dir = "/home/djl34/lab_pd/kl/data"
scratch_dir = "/n/scratch3/users/d/djl34"

# %% [markdown]
# ## get a list of genes that are AD and lof

# %%
filename = aso_data_dir + "/Clingen-Gene-Disease-Summary-2023-06-24.csv"
df = pd.read_csv(filename)

filename = aso_data_dir + "/Clingen-Dosage-Sensitivity-2023-06-25.csv"
df_ds = pd.read_csv(filename)
df_ds_haploinsufficient = df_ds[df_ds["HAPLOINSUFFICIENCY"].isin(['Sufficient Evidence for Haploinsufficiency', 'Emerging Evidence for Haploinsufficiency'])]

# %%
df_ds["HAPLOINSUFFICIENCY"].unique()
# Out:
# array(['Gene Associated with Autosomal Recessive Phenotype',
#        'Sufficient Evidence for Haploinsufficiency',
#        'No Evidence for Haploinsufficiency',
#        'Little Evidence for Haploinsufficiency',
#        'Emerging Evidence for Haploinsufficiency',
#        'Dosage Sensitivity Unlikely'], dtype=object)

# %%
df["CLASSIFICATION"].unique()
# Out:
# array(['Disputed', 'Definitive', 'Moderate', 'Limited',
#        'No Known Disease Relationship', 'Strong', 'Refuted'], dtype=object)

# %%
df_AD = df[df["MOI"] == "AD"]

df_AD_strong = df_AD[df_AD["CLASSIFICATION"].isin(["Strong", "Definitive"])]

df_AD_strong_lof = df_AD_strong.merge(df_ds_haploinsufficient, on = "GENE SYMBOL", how = "inner")

# %%
gene_list = list(df_AD_strong_lof["GENE SYMBOL"].unique())

# %%
len(gene_list)
# Out:
# 191

# %%
filename = pd_data_dir + "/biomart/ENSG_Genename_syn.tsv"
df_ensg = pd.read_csv(filename, sep = "\t")
df_ensg = df_ensg.rename({"Gene name": "GENE SYMBOL", "Gene stable ID" : "Gene"}, axis = 1)
df_ensg = df_ensg[["GENE SYMBOL", "Gene", "Chromosome/scaffold name"]].drop_duplicates()
df_ensg = df_ensg[df_ensg["Chromosome/scaffold name"].str.contains("CHR") == False]
df_ensg = df_ensg.rename({"Gene name": "GENE SYMBOL", "Gene stable ID" : "Gene"}, axis = 1)

df_AD_strong_lof_ensg = df_AD_strong_lof.merge(df_ensg, on = "GENE SYMBOL", how = "left")

ensg_gene_list = list(df_AD_strong_lof_ensg["Gene"].unique())

# %% [markdown]
# ## combine with lof data

# %%
filename = aso_data_dir + "/fake_transcript_variants_v4_lof_HC_filtered_unint.tsv"
df_lof = pd.read_csv(filename, sep = "\t")

# %%
df_lof.columns
# Out:
# Index(['Gene', 'Feature', 'Chrom', 'Pos', 'Allele_ref', 'Allele',
#        'Consequence', 'UNIPROT_ISOFORM', 'gnomAD_AF', 'gnomAD_NFE_AF',
#        'LoF_flags', 'CANONICAL', 'mu_nonhyper', 'mu_hypermut', 'mu_quality',
#        'context', 'mean', 'median', 'over_1', 'over_5', 'over_10', 'over_15',
#        'over_20', 'over_25', 'over_30', 'over_50', 'over_100', 'filter', 'AN',
#        'AN_nfe', 'AC', 'AC_nfe', 'controls_AN', 'controls_AC', 'non_cancer_AN',
#        'non_cancer_AC', 'BaseQRankSum', 'ClippingRankSum', 'DP', 'FS',
#        'InbreedingCoeff', 'MQ', 'MQRankSum', 'QD', 'ReadPosRankSum', 'SOR',
#        'VQSLOD', 'VQSR_NEGATIVE_TRAIN_SITE', 'VQSR_POSITIVE_TRAIN_SITE',
#        'VQSR_culprit', 'allele_type', 'dp_hist_all_n_larger',
#        'dp_hist_alt_n_larger', 'has_star', 'lcr', 'n_alt_alleles', 'pab_max',
#        'rf_label', 'rf_negative_label', 'rf_positive_label',
#        'rf_tp_probability_label', 'interp_dist', 'site_in_genome_bottle',
#        'ref_alt', 'Carlson_rate', 'tri', 'methylation_level', 'gnomAD_rate',
#        'mu', 'AC_unint', 'AC_nfe_unint'],
#       dtype='object')

# %%
df_lof = df_lof[["Gene", "Chrom", "Pos", "Allele_ref", "Allele", "Consequence", "LoF_flags", "filter", "mu", "AN", "AC_unint", "AN_nfe", "AC_nfe_unint"]]

# %%
df_AD_strong_lof_ensg = df_AD_strong_lof.merge(df_ensg, on = "GENE SYMBOL", how = "left")

# %%
df_AD_strong_lof_ensg["Chromosome/scaffold name"].unique()
# Out:
# array(['12', '20', '1', '4', '16', '5', '2', '6', '18', '11', '7', '10',
#        '3', '17', '13', '9', '15', '8', '14', '22', '21', '19'],
#       dtype=object)

# %%
df_AD_strong_lof_ensg = df_AD_strong_lof_ensg[["GENE SYMBOL", "Gene", "DISEASE LABEL", "MOI", "CLASSIFICATION", "GCEP", "HAPLOINSUFFICIENCY"]]

# %%
df_AD_strong_lof_ensg[["GENE SYMBOL", "Gene"]].drop_duplicates()
# Out:
#     GENE SYMBOL             Gene
# 0        ACVRL1  ENSG00000139567
# 1          ADNP  ENSG00000101126
# 2         AHDC1  ENSG00000126705
# 3          ANK2  ENSG00000145362
# 4       ANKRD11  ENSG00000167522
# ..          ...              ...
# 217         VHL  ENSG00000134086
# 218         WAC  ENSG00000095787
# 219         WT1  ENSG00000184937
# 221        ZEB2  ENSG00000169554
# 222      ZNF462  ENSG00000148143
#
# [191 rows x 2 columns]

# %%
df_AD_strong_lof_ensg[["GENE SYMBOL", "DISEASE LABEL", "HAPLOINSUFFICIENCY"]].to_csv("../data/genes_AD_lof_strong.tsv",
                                                                                    sep = "\t", index = None)

# %%
df_AD_strong_lof_ensg_variants = df_AD_strong_lof_ensg[["GENE SYMBOL", "Gene"]].drop_duplicates().merge(df_lof, on = "Gene", how = "left")

# %%
# df_AD_strong_lof_ensg_variants.to_csv("../data/variants_AD_lof_strong.tsv", sep = "\t", index = None)

# %% [markdown]
# ## filter by splice acceptor variants

# %%
df_AD_strong_lof_ensg_variants = df_AD_strong_lof_ensg_variants[df_AD_strong_lof_ensg_variants["Chrom"].isna() == False]
df_AD_strong_lof_ensg_variants["Chrom"] = df_AD_strong_lof_ensg_variants["Chrom"].astype(int)
# Out:
# /tmp/ipykernel_13654/2367571652.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AD_strong_lof_ensg_variants["Chrom"] = df_AD_strong_lof_ensg_variants["Chrom"].astype(int)

# %%
df_variants = df_AD_strong_lof_ensg_variants[df_AD_strong_lof_ensg_variants["Chrom"].isna() == False]

# %%
df_variants = df_AD_strong_lof_ensg_variants[df_AD_strong_lof_ensg_variants["Chrom"] == 22]

# %%
df_AD_strong_lof_ensg_variants["Chrom"].unique()
# Out:
# array([12., 20.,  1.,  4., 16.,  5.,  2.,  6., 18., 11.,  7., 10.,  3.,
#        17., 13.,  9., 15.,  8., 14., 22., 21., 19., nan])

# %%
df_variants["Consequence"].unique()
# Out:
# array(['stop_gained', 'splice_acceptor_variant', 'splice_donor_variant',
#        'stop_gained&splice_region_variant'], dtype=object)

# %%
df_variants = df_variants[(df_variants["Consequence"].str.contains("splice_acceptor_variant")) | (df_variants["Consequence"].str.contains("splice_donor_variant"))]

# %%
df_variants
# Out:
#       GENE SYMBOL             Gene  Chrom         Pos Allele_ref Allele  \
# 19789       CHEK2  ENSG00000183765     22  28687987.0          C      A
# 19790       CHEK2  ENSG00000183765     22  28687987.0          C      T
# 19791       CHEK2  ENSG00000183765     22  28687987.0          C      G
# 19792       CHEK2  ENSG00000183765     22  28687988.0          T      G
# 19793       CHEK2  ENSG00000183765     22  28687988.0          T      C
# ...           ...              ...    ...         ...        ...    ...
# 76699      TNRC6B  ENSG00000100354     22  40322852.0          A      C
# 76700      TNRC6B  ENSG00000100354     22  40322852.0          A      G
# 76701      TNRC6B  ENSG00000100354     22  40322852.0          A      T
# 76702      TNRC6B  ENSG00000100354     22  40322853.0          G      C
# 76703      TNRC6B  ENSG00000100354     22  40322853.0          G      T
#
#                    Consequence LoF_flags filter     mu  AN  AC_unint  AN_nfe  \
# 19789  splice_acceptor_variant         .    NaN  0.041 NaN       NaN     NaN
# 19790  splice_acceptor_variant         .    NaN  0.105 NaN       NaN     NaN
# 19791  splice_acceptor_variant         .    NaN  0.041 NaN       NaN     NaN
# 19792  splice_acceptor_variant         .    NaN  0.030 NaN       NaN     NaN
# 19793  splice_acceptor_variant         .    NaN  0.094 NaN       NaN     NaN
# ...                        ...       ...    ...    ...  ..       ...     ...
# 76699  splice_acceptor_variant         .    NaN  0.030 NaN       NaN     NaN
# 76700  splice_acceptor_variant         .    NaN  0.139 NaN       NaN     NaN
# 76701  splice_acceptor_variant         .    NaN  0.030 NaN       NaN     NaN
# 76702  splice_acceptor_variant         .    NaN  0.073 NaN       NaN     NaN
# 76703  splice_acceptor_variant         .    NaN  0.041 NaN       NaN     NaN
#
#        AC_nfe_unint
# 19789           NaN
# 19790           NaN
# 19791           NaN
# 19792           NaN
# 19793           NaN
# ...             ...
# 76699           NaN
# 76700           NaN
# 76701           NaN
# 76702           NaN
# 76703           NaN
#
# [1024 rows x 14 columns]

# %%
df_variants.to_csv("../data/variants_splice_acceptor_donor_AD_lof_strong.tsv", sep = "\t", index = None)

# %%
df_variants
# Out:
#       GENE SYMBOL             Gene  Chrom          Pos Allele_ref Allele  \
# 3          ACVRL1  ENSG00000139567   12.0   51913097.0          A      G
# 4          ACVRL1  ENSG00000139567   12.0   51913097.0          A      T
# 5          ACVRL1  ENSG00000139567   12.0   51913098.0          G      C
# 6          ACVRL1  ENSG00000139567   12.0   51913098.0          G      A
# 23         ACVRL1  ENSG00000139567   12.0   51913351.0          G      C
# ...           ...              ...    ...          ...        ...    ...
# 96717      ZNF462  ENSG00000148143    9.0  107009670.0          T      G
# 96718      ZNF462  ENSG00000148143    9.0  107010821.0          A      T
# 96719      ZNF462  ENSG00000148143    9.0  107010821.0          A      C
# 96720      ZNF462  ENSG00000148143    9.0  107010822.0          G      C
# 96721      ZNF462  ENSG00000148143    9.0  107010822.0          G      A
#
#                    Consequence    LoF_flags filter     mu        AN  AC_unint  \
# 3      splice_acceptor_variant  NAGNAG_SITE    NaN  0.139       NaN       NaN
# 4      splice_acceptor_variant  NAGNAG_SITE    NaN  0.020       NaN       NaN
# 5      splice_acceptor_variant  NAGNAG_SITE     RF  0.020  232218.0       0.0
# 6      splice_acceptor_variant  NAGNAG_SITE     RF  0.094  232218.0       1.0
# 23        splice_donor_variant            .    NaN  0.051       NaN       NaN
# ...                        ...          ...    ...    ...       ...       ...
# 96717     splice_donor_variant            .    NaN  0.020       NaN       NaN
# 96718  splice_acceptor_variant            .    NaN  0.020       NaN       NaN
# 96719  splice_acceptor_variant            .    NaN  0.030       NaN       NaN
# 96720  splice_acceptor_variant            .    NaN  0.051       NaN       NaN
# 96721  splice_acceptor_variant            .    NaN  0.094       NaN       NaN
#
#          AN_nfe  AC_nfe_unint
# 3           NaN           NaN
# 4           NaN           NaN
# 5      105398.0           0.0
# 6      105398.0           1.0
# 23          NaN           NaN
# ...         ...           ...
# 96717       NaN           NaN
# 96718       NaN           NaN
# 96719       NaN           NaN
# 96720       NaN           NaN
# 96721       NaN           NaN
#
# [31874 rows x 14 columns]

# %%
for x in list(df_AD_strong_lof_ensg["DISEASE LABEL"].unique()):
    print(x, end = ", ")
# Out:
# telangiectasia, hereditary hemorrhagic, type 2, ADNP-related multiple congenital anomalies - intellectual disability - autism spectrum disorder, AHDC1-related intellectual disability - obstructive sleep apnea - mild dysmorphism syndrome, complex neurodevelopmental disorder, KBG syndrome, syndromic intellectual disability, gastric adenocarcinoma and proximal polyposis of the stomach, classic or attenuated familial adenomatous polyposis, hypercholesterolemia, autosomal dominant, type B, Coffin-Siris syndrome, Bohring-Opitz syndrome, hereditary breast carcinoma, myofibrillar myopathy, dilated cardiomyopathy, BAP1-related tumor predisposition syndrome, Dias-Logan syndrome, juvenile polyposis syndrome, pulmonary arterial hypertension, breast-ovarian cancer, familial, susceptibility to, 1, breast-ovarian cancer, familial, susceptibility to, 2, familial ovarian cancer, hyperparathyroidism 2 with jaw tumors, hereditary diffuse gastric adenocarcinoma, multiple endocrine neoplasia type 4, melanoma-pancreatic cancer syndrome, CHARGE syndrome, osteogenesis imperfecta type 2, osteogenesis imperfecta type 1, osteogenesis imperfecta type 3, spondyloepiphyseal dysplasia congenita, achondrogenesis type II, Kniest dysplasia, platyspondylic dysplasia, Torrance type, spondyloperipheral dysplasia, spondylometaphyseal dysplasia, Ehlers-Danlos syndrome, vascular type, Ehlers-Danlos syndrome, classic type, Rubinstein-Taybi syndrome, severe intellectual disability-progressive spastic diplegia syndrome, pseudohypoaldosteronism type 2E, Brooke-Spiegler syndrome, DDX41-related hematologic malignancy predisposition syndrome, pleuropulmonary blastoma, familial isolated arrhythmogenic right ventricular dysplasia, arrhythmogenic right ventricular cardiomyopathy, arrhythmogenic cardiomyopathy with woolly hair and keratoderma, mandibulofacial dysostosis-microcephaly syndrome, Kleefstra syndrome, hereditary hemorrhagic telangiectasia, Rubinstein-Taybi syndrome due to EP300 haploinsufficiency, craniosynostosis 4, thrombocytopenia 5, exostoses, multiple, type 1, exostoses, multiple, type 2, branchio-oto-renal syndrome, nonsyndromic genetic hearing loss, familial thoracic aortic aneurysm and aortic dissection, Marfan syndrome, Pfeiffer syndrome type 1, hereditary leiomyomatosis and renal cell cancer, Birt-Hogg-Dube syndrome, myofibrillar myopathy 5, anterior segment dysgenesis 3, FOXG1 disorder, intellectual disability-severe speech delay-mild dysmorphism syndrome, GATA2 deficiency with susceptibility to MDS/AML, hypoparathyroidism-deafness-renal disease syndrome, structural congenital heart disease, multiple types - GATA4, severe intellectual disability-poor language-strabismus-grimacing face-long fingers syndrome, renal cysts and diabetes syndrome, neurodevelopmental disorder-craniofacial dysmorphism-cardiac defect-hip dysplasia syndrome, Koolen-de Vries syndrome, KAT6B-related multiple congenital anomalies syndrome, long QT syndrome, short QT syndrome, neonatal-onset developmental and epileptic encephalopathy, microcephaly with or without chorioretinopathy, lymphedema, or intellectual disability, Wiedemann-Steiner syndrome, complex neurodevelopmental disorder with motor features, Kabuki syndrome 1, nail-patella syndrome, hereditary pheochromocytoma-paraganglioma, multiple endocrine neoplasia type 1, Waardenburg syndrome type 2, Lynch syndrome, hypertrophic cardiomyopathy, neurofibromatosis type 1, neurofibromatosis type 2, brain malformations with or without urinary tract defects, Marshall-Smith syndrome, Malan overgrowth syndrome, Cornelia de Lange syndrome, Bosch-Boonstra-Schaaf optic atrophy syndrome, autosomal dominant pseudohypoaldosteronism type 1, Sotos syndrome, focal segmental glomerulosclerosis 7, Waardenburg syndrome, PAX6-related ocular dysgenesis, congenital anomalies of kidney and urinary tract syndrome with or without hearing loss, abnormal ears, or developmental delay, PHIP-related behavioral problems-intellectual disability-obesity-dysmorphic f ...

# %%
df_variants[["GENE SYMBOL", "DISEASE LABEL", "HAPLOINSUFFICIENCY"]].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df_variants[["GENE SYMBOL", "DISEASE LABEL", "HAPLOINSUFFICIENCY"]].drop_duplicates()
#
# File ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['DISEASE LABEL', 'HAPLOINSUFFICIENCY'] not in index"

# %%
len(df_variants["GENE SYMBOL"].unique())
# Out:
# 186

# %%
len(df_variants)
# Out:
# 15981

# %%
df_variants["mu_pergen"] = df_variants["mu"] * 1.015 * 10 **-7
# Out:
# /var/folders/wx/z2j6vh_s593cjs7xx71k0q780000gq/T/ipykernel_8592/1573240805.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_variants["mu_pergen"] = df_variants["mu"] * 1.015 * 10 **-7

# %%
df_variants["mu_pergen"].sum()
# Out:
# 0.00022304493049999993

# %%
1/df_variants["mu_pergen"].sum()
# Out:
# 4483.401607731229

# %%
3.66*10**6 / 4483.401607731229
# Out:
# 816.3444456299998

# %%
df_variants["LoF_flags"].unique()
# Out:
# array(['NAGNAG_SITE', '.', 'NON_CAN_SPLICE'], dtype=object)

# %%
df_variants
# Out:
#        GENE SYMBOL             Gene  \
# 3           ACVRL1  ENSG00000139567
# 4           ACVRL1  ENSG00000139567
# 5           ACVRL1  ENSG00000139567
# 6           ACVRL1  ENSG00000139567
# 28          ACVRL1  ENSG00000139567
# ...            ...              ...
# 111537      ZNF462  ENSG00000148143
# 111547      ZNF462  ENSG00000148143
# 111548      ZNF462  ENSG00000148143
# 111549      ZNF462  ENSG00000148143
# 111550      ZNF462  ENSG00000148143
#
#                                          DISEASE LABEL MOI CLASSIFICATION  \
# 3       telangiectasia, hereditary hemorrhagic, type 2  AD     Definitive
# 4       telangiectasia, hereditary hemorrhagic, type 2  AD     Definitive
# 5       telangiectasia, hereditary hemorrhagic, type 2  AD     Definitive
# 6       telangiectasia, hereditary hemorrhagic, type 2  AD     Definitive
# 28      telangiectasia, hereditary hemorrhagic, type 2  AD     Definitive
# ...                                                ...  ..            ...
# 111537                          weiss-kruszka syndrome  AD     Definitive
# 111547                          weiss-kruszka syndrome  AD     Definitive
# 111548                          weiss-kruszka syndrome  AD     Definitive
# 111549                          weiss-kruszka syndrome  AD     Definitive
# 111550                          weiss-kruszka syndrome  AD     Definitive
#
#                          GCEP                          HAPLOINSUFFICIENCY  \
# 3       Hemostasis Thrombosis  Sufficient Evidence for Haploinsufficiency
# 4       Hemostasis Thrombosis  Sufficient Evidence for Haploinsufficiency
# 5       Hemostasis Thrombosis  Sufficient Evidence for Haploinsufficiency
# 6       Hemostasis Thrombosis  Sufficient Evidence for Haploinsufficiency
# 28      Hemostasis Thrombosis  Sufficient Evidence for Haploinsufficiency
# ...                       ...                                         ...
# 111537    Syndromic Disorders  Sufficient Evidence for Haploinsufficiency
# 111547    Syndromic Disorders  Sufficient Evidence for Haploinsufficiency
# 111548    Syndromic Disorders  Sufficient Evidence for Haploinsufficiency
# 111549    Syndromic Disorders  Sufficient Evidence for Haploinsufficiency
# 111550    Syndromic Disorders  Sufficient Evidence for Haploinsufficiency
#
#         Chrom          Pos Allele_ref Allele              Consequence  \
# 3        12.0   51913097.0          A      G  splice_acceptor_variant
# 4        12.0   51913097.0          A      T  splice_acceptor_variant
# 5        12.0   51913098.0          G      C  splice_acceptor_variant
# 6        12.0   51913098.0          G      A  splice_acceptor_variant
# 28       12.0   51913557.0          A      T  splice_acceptor_variant
# ...       ...          ...        ...    ...                      ...
# 111537    9.0  107009544.0          G      T  splice_acceptor_variant
# 111547    9.0  107010821.0          A      T  splice_acceptor_variant
# 111548    9.0  107010821.0          A      C  splice_acceptor_variant
# 111549    9.0  107010822.0          G      C  splice_acceptor_variant
# 111550    9.0  107010822.0          G      A  splice_acceptor_variant
#
#           LoF_flags filter     mu        AN  AC_unint    AN_nfe  AC_nfe_unint  \
# 3       NAGNAG_SITE    NaN  0.139       NaN       NaN       NaN           NaN
# 4       NAGNAG_SITE    NaN  0.020       NaN       NaN       NaN           NaN
# 5       NAGNAG_SITE     RF  0.020  232218.0       0.0  105398.0           0.0
# 6       NAGNAG_SITE     RF  0.094  232218.0       1.0  105398.0           1.0
# 28                .    NaN  0.020       NaN       NaN       NaN           NaN
# ...             ...    ...    ...       ...       ...       ...           ...
# 111537            .    NaN  0.020       NaN       NaN       NaN           NaN
# 111547            .    NaN  0.020       NaN       NaN       NaN           NaN
# 111548            .    NaN  0.030       NaN       NaN       NaN           NaN
# 111549            .    NaN  0.051       NaN       NaN       NaN           NaN
# 111550            .    NaN  0.094       NaN       NaN       NaN           NaN
#
#            mu_pergen
# 3       1.410850e-08
# 4       2.030000e-09
# 5       2.030000e-09
# 6       9.541000e-09
# 28      2.030000e-09
# ...              ...
# 111537  2.030000e-09
# 111547  2.030000e-09
# 111548  3.045000e-09
# 111549  5.176500e-09
# 111550  9.541000e-09
#
# [19599 rows x 20 columns]
