# %%
import os
import dask.dataframe as dd
from dask.distributed import Client
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)


pd_data_dir = "/home/djl34/lab_pd/data"
aso_data_dir = "/home/djl34/lab_pd/aso/data"
KL_data_dir = "/home/djl34/lab_pd/kl/data"
scratch_dir = "/n/scratch3/users/d/djl34"

# %% [markdown]
# ## get a list of genes that are AD and lof

# %%
filename = aso_data_dir + "/Clingen-Gene-Disease-Summary-2023-06-24.csv"
df = pd.read_csv(filename)

filename = aso_data_dir + "/Clingen-Dosage-Sensitivity-2023-06-25.csv"
df_ds = pd.read_csv(filename)
df_ds_haploinsufficient = df_ds[df_ds["HAPLOINSUFFICIENCY"].isin(['Sufficient Evidence for Haploinsufficiency', 'Emerging Evidence for Haploinsufficiency'])]

# %%
df_ds["HAPLOINSUFFICIENCY"].unique()
# Out:
# array(['Gene Associated with Autosomal Recessive Phenotype',
#        'Sufficient Evidence for Haploinsufficiency',
#        'No Evidence for Haploinsufficiency',
#        'Little Evidence for Haploinsufficiency',
#        'Emerging Evidence for Haploinsufficiency',
#        'Dosage Sensitivity Unlikely'], dtype=object)

# %%
df["CLASSIFICATION"].unique()
# Out:
# array(['Disputed', 'Definitive', 'Moderate', 'Limited',
#        'No Known Disease Relationship', 'Strong', 'Refuted'], dtype=object)

# %%
df_AD = df[df["MOI"] == "AD"]

df_AD_strong = df_AD[df_AD["CLASSIFICATION"].isin(["Strong", "Definitive"])]

# %%
df_AD_strong
# Out:
#      GENE SYMBOL GENE ID (HGNC)  \
# 25         ACOX1       HGNC:119
# 31         ACTA2       HGNC:130
# 33          ACTB       HGNC:132
# 34         ACTC1       HGNC:143
# 37         ACTG1       HGNC:144
# ...          ...            ...
# 2160       YARS1     HGNC:12840
# 2166        ZEB2     HGNC:14881
# 2167       ZMIZ1     HGNC:16493
# 2171      ZNF292     HGNC:18410
# 2174      ZNF462     HGNC:21684
#
#                                           DISEASE LABEL DISEASE ID (MONDO)  \
# 25                                    Mitchell syndrome      MONDO:0030073
# 31    familial thoracic aortic aneurysm and aortic d...      MONDO:0019625
# 33        Baraitser-Winter cerebrofrontofacial syndrome      MONDO:0017579
# 34                          hypertrophic cardiomyopathy      MONDO:0005045
# 37                          Baraitser-winter syndrome 2      MONDO:0013812
# ...                                                 ...                ...
# 2160                        Charcot-Marie-Tooth disease      MONDO:0015626
# 2166                              Mowat-Wilson syndrome      MONDO:0009341
# 2167                complex neurodevelopmental disorder      MONDO:0100038
# 2171                complex neurodevelopmental disorder      MONDO:0100038
# 2174                             weiss-kruszka syndrome      MONDO:0032836
#
#      MOI   SOP CLASSIFICATION  \
# 25    AD  SOP9         Strong
# 31    AD  SOP4     Definitive
# 33    AD  SOP8     Definitive
# 34    AD  SOP8     Definitive
# 37    AD  SOP6     Definitive
# ...   ..   ...            ...
# 2160  AD  SOP7     Definitive
# 2166  AD  SOP5     Definitive
# 2167  AD  SOP9     Definitive
# 2171  AD  SOP7     Definitive
# 2174  AD  SOP7     Definitive
#
#                                           ONLINE REPORT  \
# 25    https://search.clinicalgenome.org/kb/gene-vali...
# 31    https://search.clinicalgenome.org/kb/gene-vali...
# 33    https://search.clinicalgenome.org/kb/gene-vali...
# 34    https://search.clinicalgenome.org/kb/gene-vali...
# 37    https://search.clinicalgenome.org/kb/gene-vali...
# ...                                                 ...
# 2160  https://search.clinicalgenome.org/kb/gene-vali...
# 2166  https://search.clinicalgenome.org/kb/gene-vali...
# 2167  https://search.clinicalgenome.org/kb/gene-vali...
# 2171  https://search.clinicalgenome.org/kb/gene-vali...
# 2174  https://search.clinicalgenome.org/kb/gene-vali...
#
#            CLASSIFICATION DATE  \
# 25    2022-12-29T17:00:00.000Z
# 31         2016-09-27T00:00:00
# 33    2021-10-26T16:58:35.977Z
# 34    2021-06-23T20:16:16.296Z
# 37    2019-01-07T17:00:00.000Z
# ...                        ...
# 2160  2020-04-28T16:00:00.000Z
# 2166  2018-05-24T16:00:00.000Z
# 2167  2022-07-05T02:00:00.000Z
# 2171  2020-05-06T16:00:00.000Z
# 2174  2020-08-25T13:10:51.689Z
#
#                                                    GCEP
# 25                                Peroxisomal Disorders
# 31    Heritable Thoracic Aortic Aneurysm and Dissection
# 33                                  Brain Malformations
# 34                          Hypertrophic Cardiomyopathy
# 37                                         Hearing Loss
# ...                                                 ...
# 2160                                Charcot-Marie-Tooth
# 2166                 Intellectual Disability and Autism
# 2167                 Intellectual Disability and Autism
# 2171                 Intellectual Disability and Autism
# 2174                                Syndromic Disorders
#
# [541 rows x 10 columns]

# %%
df_AD_strong_lof = df_AD_strong.merge(df_ds_haploinsufficient, on = "GENE SYMBOL", how = "inner")

# %%
gene_list = list(df_AD_strong_lof["GENE SYMBOL"].unique())

# %%
all_ad_gene_list = list(df_AD_strong["GENE SYMBOL"].unique())

# %%
set(all_ad_gene_list) - set(gene_list)
# Out:
# {'ACOX1',
#  'ACTA2',
#  'ACTB',
#  'ACTC1',
#  'ACTG1',
#  'ACTN1',
#  'AKT3',
#  'ALK',
#  'ALPL',
#  'ANK1',
#  'ANKRD26',
#  'ANXA11',
#  'ASXL2',
#  'ATL1',
#  'ATP1A2',
#  'ATP1A3',
#  'BRAF',
#  'BRD4',
#  'BRSK2',
#  'BSCL2',
#  'C9orf72',
#  'CALM1',
#  'CALM2',
#  'CALM3',
#  'CAPN5',
#  'CARD11',
#  'CAV1',
#  'CAV3',
#  'CBL',
#  'CDC42',
#  'CDK4',
#  'CEBPA',
#  'CHD3',
#  'CHMP2B',
#  'CHRNA4',
#  'CHRNB2',
#  'CNOT3',
#  'COCH',
#  'COL11A2',
#  'COL5A2',
#  'COL6A1',
#  'COL6A2',
#  'COL6A3',
#  'COMP',
#  'CSNK2B',
#  'CTLA4',
#  'CXCR4',
#  'DCC',
#  'DEPDC5',
#  'DES',
#  'DIAPH1',
#  'DNAJB11',
#  'DNAJB6',
#  'DNM1',
#  'DNM1L',
#  'DNM2',
#  'DNMT1',
#  'DSPP',
#  'EEF1A2',
#  'EFEMP1',
#  'EGFR',
#  'EIF2S3',
#  'ELANE',
#  'ELOVL4',
#  'EPCAM',
#  'EPHB4',
#  'EZH2',
#  'F2',
#  'F5',
#  'FGFR2',
#  'FGFR3',
#  'FLT4',
#  'FOXJ1',
#  'FOXP2',
#  'FUS',
#  'GABRA1',
#  'GABRB3',
#  'GABRG2',
#  'GANAB',
#  'GARS1',
#  'GBA',
#  'GCK',
#  'GDF2',
#  'GFI1B',
#  'GJB3',
#  'GJB6',
#  'GLUD1',
#  'GNAI1',
#  'GNAO1',
#  'GP1BA',
#  'GREM1',
#  'GRHL2',
#  'GRIA2',
#  'GRIK2',
#  'GRIN1',
#  'GRIN2D',
#  'GRN',
#  'GSDME',
#  'GUCY2D',
#  'HBB',
#  'HEPACAM',
#  'HNF1A',
#  'HNF4A',
#  'HNRNPU',
#  'HRAS',
#  'HSPB1',
#  'HSPB8',
#  'HTT',
#  'IFT140',
#  'IKZF1',
#  'INF2',
#  'INS',
#  'ITPR1',
#  'KCNA1',
#  'KCNA2',
#  'KCNB1',
#  'KCNC1',
#  'KCNH1',
#  'KCNH5',
#  'KCNJ11',
#  'KCNK3',
#  'KCNMA1',
#  'KCNQ4',
#  'KCNT1',
#  'KDM6B',
#  'KDR',
#  'KIF1A',
#  'KIF21A',
#  'KIF5A',
#  'KIT',
#  'KRAS',
#  'LGI1',
#  'LOX',
#  'LRRK2',
#  'LZTR1',
#  'MAGEL2',
#  'MAP2K1',
#  'MAP2K2',
#  'MAPK8IP3',
#  'MECOM',
#  'MED13',
#  'MET',
#  'MORC2',
#  'MPL',
#  'MPZ',
#  'MSX2',
#  'MTOR',
#  'MUC1',
#  'MYH11',
#  'MYH7',
#  'MYH9',
#  'MYL2',
#  'MYL3',
#  'MYLK',
#  'MYO6',
#  'MYO7A',
#  'NEDD4L',
#  'NEFH',
#  'NEFL',
#  'NEK1',
#  'NFKB1',
#  'NFKB2',
#  'NOD2',
#  'NPRL3',
#  'NRAS',
#  'NSD2',
#  'OPTN',
#  'ORAI1',
#  'PACS1',
#  'PALB2',
#  'PCGF2',
#  'PCSK9',
#  'PDGFRA',
#  'PFN1',
#  'PHOX2B',
#  'PIK3CA',
#  'PIK3CD',
#  'PIK3R1',
#  'PIK3R2',
#  'PLN',
#  'POLD1',
#  'POLE',
#  'POU4F3',
#  'PPM1D',
#  'PPP1CB',
#  'PPP1R12A',
#  'PPP2R1A',
#  'PPP2R5D',
#  'PRKAG2',
#  'PRKAR1A',
#  'PRKCSH',
#  'PRKG1',
#  'PROKR2',
#  'PRPF31',
#  'PRPF8',
#  'PRSS1',
#  'PUF60',
#  'QRICH1',
#  'RAB7A',
#  'RAC2',
#  'RAF1',
#  'RBM20',
#  'REN',
#  'RERE',
#  'RHBDF2',
#  'RIT1',
#  'RNF43',
#  'RPE65',
#  'RPL5',
#  'RPS10',
#  'RRAS2',
#  'RYR1',
#  'RYR2',
#  'SCN11A',
#  'SCN1B',
#  'SCN3A',
#  'SCN8A',
#  'SCNN1G',
#  'SDHA',
#  'SEC63',
#  'SERPIND1',
#  'SERPING1',
#  'SERPINI1',
#  'SET',
#  'SETX',
#  'SHOC2',
#  'SIX1',
#  'SKI',
#  'SLC17A8',
#  'SLC1A2',
#  'SLC1A3',
#  'SMAD9',
#  'SMARCA2',
#  'SMARCC2',
#  'SMARCE1',
#  'SMC3',
#  'SMCHD1',
#  'SNAP25',
#  'SNCA',
#  'SNRNP200',
#  'SOD1',
#  'SOS1',
#  'SOS2',
#  'SOX17',
#  'SPI1',
#  'SPTAN1',
#  'SPTLC2',
#  'SSBP1',
#  'STAT3',
#  'STIM1',
#  'SUFU',
#  'TANC2',
#  'TAOK1',
#  'TARDBP',
#  'TBK1',
#  'TCF7L2',
#  'TECTA',
#  'TEK',
#  'TGFB2',
#  'TIMP3',
#  'TMC1',
#  'TMEM43',
#  'TNNC1',
#  'TNNI3',
#  'TNNT2',
#  'TOPORS',
#  'TPM1',
#  'TPM2',
#  'TRIM8',
#  'TRPV4',
#  'TRRAP',
#  'TTR',
#  'TUBB1',
#  'TUBB2A',
#  'TUBB2B',
#  'TUBG1',
#  'UMOD',
#  'USP7',
#  'VAPB',
#  'VCAN',
#  'VCP',
#  'VPS35',
#  'VWF',
#  'WDFY3',
#  'WFS1',
#  'YARS1',
#  'ZMIZ1',
#  'ZNF292'}
